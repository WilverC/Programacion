# %%
def fibonacci(elementos):
    # primeros 2 elementos
    x1 = 0
    x2 = 1
    contador = ____

    while ____ < ____:
        if contador < ____:
            contador += 1
            yield ____
        else:
            n = ____ + ____
            x1 = ____
            x2 = ____
            contador ____
            yield n


iteraciones = 10
fib = fibonacci(____)

for i in range(iteraciones):
    print(next(fib))
