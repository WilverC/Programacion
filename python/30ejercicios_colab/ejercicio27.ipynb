# %%
import numpy as np
from sklearn.datasets import ____

boston = load_boston()

print("X.shape =", boston.____.shape)
print("Y.shape =", type(boston.____.shape))

x_list = []
y_list = []

for i, (x, y) in enumerate(zip(____.____, ____.____)):
    temp = []
    if i == 10:
        ____  # Terminar el ciclo for
    print("dato %d :" % i)
    print("X= [", end = '')
    for valor in x:
        temp.____(round(valor * 100, 2))
        print(valor , end = '')

    print("]\nY= ", y)
    print("\n----")
    x_list.append(temp)
    y_list.append(____)

# %%
for x, y in zip(x_list, y_list):
    print(x, y)
    print()

____.savez("numpy_zip.npz", X=____, Y=____)

# %%
archivo_numpy = np.____("numpy_zip.npz")
n_x = archivo_numpy[____]
n_y = archivo_numpy[____]

for x, y in zip(n_x, n_y):
  
  print("X= ",end = '')
  for val in x:
    print("{:.2f}".format(____), end = '')
  print("\nY= ", y)
