# %%
import ____
import ____

# Datos:
x = np.arange(____, ____, ____)  # Valores de X

y1 = map(____ x: ____, ____)
y2 = map(____ x: ____, ____)

# Otra forma de usar los plot es:
plt.figure(figsize=(5, 5))  # Crea la figura de un tamaño definido
plt.plot(list(____))  # Dibuja la función y1
plt.plot(list(____))  # Dibuja la función y2
plt.xlim((-200, 400))  # Delimita los valores en el eje X
plt.show()
