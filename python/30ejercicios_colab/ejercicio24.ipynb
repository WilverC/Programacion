# %%
import cv2
import numpy as np
import os

nombres = [____, ____, ____, ____]
imagenes = []

for archivo in nombres:
  imagenes.append(____.imread(os.path.____("images", archivo)))

imagenes = np.array(imagenes)
for file in imagenes:
  print(file.shape)

# %%
nueva_carpeta = "copia"

# Crear carpeta si no exciste
if not os.path.exists(____):
    os.mkdir(____)

nuevas_imagenes = []
dimension = (____, ____)

# Reescalar imágenes
for imangen, nombre in zip(imagenes, nombres):
  
  re_img = cv2.____(imangen, dimension, interpolation = cv2.INTER_AREA)
  nuevas_imagenes.append(re_img)
  cad = nombre.split(".")
  # Ruta donde se guardará la imagen
  path = ____ + "/" + cad[0] + ".jpg"
  print(path)
  print(re_img.shape, type(re_img))
  cv2.imwrite(____, re_img)
