# %%
datos_list = ["Buenos días a todos y todas", 999999999999999, True, 125.193565145e-8]


for dato in datos_list:
    print()
    print(dato)
    if isinstance(dato, bool):
        print(____.format(dato))  # TODO: Modifique esta línea

    elif isinstance(dato, int):
        print(____.format(dato))  # TODO: Modifique esta línea

    elif isinstance(dato,float):
        print(____.format(dato))  # TODO: Modifique esta línea

    elif isinstance(dato, str):
        print(____.format(dato))  # TODO: Modifique esta línea

# %%
# Qué operador nos crea una lista con repeticiones
lista = [5] ____
print(lista)
