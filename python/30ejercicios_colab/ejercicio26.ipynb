# %%
import ____
import ____
import ____

imgname = ____  
imgCV = cv2.____(imgname)     #Imagen para visualizar

# Modificar cajas
rect_r = ((0, 0),(100, 100))
rect_v = ((50, 650),(200, 700))

# Dibujar rectángulos
cv2.____(imgCV, ____[____], ____[____], (____,____,____), 4)
cv2.____(imgCV, ____[____], ____[____], (____,____,____), 4)

# Correjir canales
imgCV = ____

plt.figure(____=(18, 18))
plt.____(imgCV)
plt.title('CV2')
plt.show()
