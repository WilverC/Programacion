# %%
import ____ as np

lista_python = ["A", "B", "C", "D", "E", "F"]
arrego_numpy = np.____(____)

print(type(lista_python))
print(type(arrego_numpy))

numeros = np.____(____, ____, ____)
print("numeros: ", numeros)
print("tipo(numeros) ", type(numeros))

matriz = np.____(____, (4, 3))
print(matriz)

matriz = np.reshape(____, ____)
print()
print(matriz)

# Descomente la siguiente linea para probar
#matriz = np.reshape(numeros, (7, 2))
print()
print(matriz)
