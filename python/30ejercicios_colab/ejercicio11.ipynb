# %%
import ____
import math

lista = []
pares = []

# Ciclo for
____ n in range(50):
    # Agregue un número aleatorio de {0 a 49]
    lista.____(____.randint(____, ____))

# Función
____ obten_pares____:
    nueeva_lista = []

    ____ item ____ ____:
        if item % ____ == ____:
            nueeva_lista.____(item)

    return ____

pares = obten_pares(____)
print(pares)
var_map = map(____ x: math.____(x), ____)
print(list(____))
