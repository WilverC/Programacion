# %%
# Defina la clase Automovil, no use acentos
class ____():

    def __init__(self):
        self.tanque = 0.0  # de [0,100]
        self.velocidad = 0.0  # de [0, 160]
        self.ocupantes = 0  # de [0, 5]
        self.encendido = False

    def encender_apagar(self):
        if ____ ____ and ____ > 0:
            self.____ = 1
            self.____ = True
        else:
            ____ = ____
            ____ = ____

        print("Encendido: %s, personas %d" %  (self.encendido, self.ocupantes))

    def cargar_gasolina(self, ____=0):
        gass = self.____ + ____
        if gass > ____:
            self.____ = ____
        else:
            self.____ = gass

        print("Gasolina: ", self.tanque)

    def conducir(self, ____=0, ____=0):
        for i in range(int(____)):
            self.____ -= ____ * ____ / ____
            if self.tanque < 0:
                ____ = ____;
                break

        print("Me quedan %f litros" % self.tanque)

    def dar_un_ray(self, ____=0):
        gente = self.____ + personas
        if gente > ____:
            self.ocupantes = 5
        elif gente < ____:
            self.ocupantes = 1
        else:
            self.ocupantes = ____

        print("Somos %d en el carro" % self.ocupantes)


# No modifique las siguientes líneas
carro = Automovil()

carro.cargar_gasolina(120)
carro.encender_apagar()
carro.conducir(80, 2)
carro.dar_un_ray(3)
carro.conducir(100, 2)
carro.encender_apagar()
