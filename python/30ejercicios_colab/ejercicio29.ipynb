# %% [markdown]
# ## Observe la figura de ejemplo para crear plots 3D

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection="3d")
x, y, z = axes3d.get_test_data(0.05)
ax.plot_wireframe(x, y, z)
plt.show()

# %% [markdown]
# ### Genere la superficie dada por la función
# ### $z = x^{2} + y^{2}$

# %%
# Cree un espacio de valores de [-100 a 100]
rango = np._____(_____, _____, 100)
# Genere un grid X, Y para plotear la superficie
X, Y = np._____(_____, _____)

# Defina la función z
def funcion_z(x, y):
  return _____

# Genere 10 puntos (x, y) aleatorios
puntos = []
px = np._____._____(_____, _____, _____)
py = np._____._____(_____, _____, _____)
print(px)
print(py)

# Cree un arreglo vertical de coordenadas (x, y)
# combinando los arreglos px y py
puntos = np._____(_____, axis=_____)

for punto in puntos:
  print("punto %s" % punto)
  print("Z= %d" % funcion_z(punto[0], punto[1]))

# %%
# Defina la figura del plot
fig = plt._____(figsize=(5, 5))
ax = fig._____(111)
# Dibuje la proyeccion 2D de la superficie con contourf
plt._____(_____, _____, funcion_z(_____))
# Dibuje los putos generados aleatoriamente con una lista de Comprensión
[plt.plot(_____[_____], _____[_____], 'ro') for punto in puntos]
plt.show()

# %%
# Realice el plot en 3D
fig = plt._____(figsize=(5, 5))
ax = fig._____(111, projection=_____)
objeto = ax._____(_____, _____, funcion_z(_____))
[ax.scatter(_____[_____], punto[1], funcion_z(_____[0], _____[1]), c='r', marker='o', s=100 ) for punto in puntos]
ax.view_init(45, 15)
