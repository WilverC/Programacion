# %%
# Módulo para manejar carpetas en el (SO)
import csv
import os

nombre_archivo = "archivo.csv"
nombre_carpeta = "folder_1"
path = os.path.join(____, ____)
diccionario = {}

with open(path, ____) as csv_file:  # Abrir el archivo
    csv_reader = csv.reader(____)
    next(____)  # le la primer línea (header)
    for fila in csv_reader:  # por cada fila en el archivo
        if len(fila) > 1:  # Si la fila tiene 2 o más datos
            print(fila)
            diccionario[int(____[____])] = ____[____]  # guardar datos

print("Diccionario:")
print(diccionario)
