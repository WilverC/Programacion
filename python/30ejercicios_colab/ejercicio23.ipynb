# %%
____ cv2
import ____ as np
import ____

nombres = []
path = "images"

# %%
imagenes = []

# listar contenido de un directorio
nombres = os.listdir(____)

for archivo in nombres:
  ruta = ____.____.join(path, archivo)
  print(ruta)
  imagenes.____(cv2.imread(____))

# Convertir a numpy array para su manipulación
imagenes = ____.asarray(imagenes)
print("\nimagenes.shape = ", imagenes.____)

# %%
for i, img in enumerate(imagenes):
  print("imagen %d shape = %s" % (____, ____.shape))
