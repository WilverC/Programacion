# %%
import cv2
import os

# listar contenido de un directorio
nombres = os.____("copia")
imagenes = []

for archivo in nombres:
  ruta = os.path.join("copia", ____)
  print(ruta)
  img = cv2.____(____)

  # ...
  imagenes.append(____)

# %%
import ____.____ as plt


plt.figure(figsize=(5, 5))
plt.subplot(2, 2, ____)
plt.imshow(imagenes[____])
# TODO: Remover ejes
plt.axis(____)

plt.subplot(2, 2, ____)
plt.imshow(imagenes[____])
# TODO: Remover ejes
plt.axis(____)

plt.subplot(2, 2, ____)
plt.imshow(imagenes[____])
# TODO: Remover ejes
plt.axis(____)

plt.subplot(2, 2, ____)
plt.imshow(imagenes[____])
# TODO: Remover ejes
plt.axis(____)

plt.show()
